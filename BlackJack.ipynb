# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')

ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}

# %%
class Card:
    
    def __init__(self,suit,rank):
        
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        
        return (f'{self.rank} of {self.suit}')
    
    def __repr__(self):
        
        return str(self)

# %%
class Deck:
    
    def __init__(self):
        self.all_cards = [] 
        
        for suit in suits: 
            for rank in ranks: 
                
                
                created_card = Card(suit,rank)
                
                self.all_cards.append(created_card)
                
    def shuffle(self): 
        random.shuffle(self.all_cards)
        
    def deal_one(self): 
        return self.all_cards.pop()

# %%
class Chips:
    
    def __init__(self,balance):
        
        self.balance = balance
    
    def cash_out(self,amount):
        
        self.balance = self.balance - amount
        
    def cash_in(self,amount):
        
        self.balance = self.balance + amount

# %%
class Player(Chips):
    
    def __init__(self,name,balance):
        
        self.name = name
        
        self.current_bet = 0
        
        self.current_bet2 = 0
        
        self.all_cards1 = []
        
        self.all_cards2 = []
        
        Chips.__init__(self,balance)
        
        print(f'{self.name} has {self.balance} dollars.')
        
    def add_cards(self,new_card):
        
        self.all_cards.append(new_card)
        
    def hit(self,new_card):
        
        self.all_cards.append(new_card)
        
    def doubleDown(self):
        
        self.current_bet = self.current_bet*2
        
    def split(self):
        
        self.all_cards2.append(self.all_cards1.pop())
        
    def reset(self):
        
        self.current_bet = 0
        
        self.current_bet2 = 0
        
        self.all_cards1 = []
        
        self.all_cards2 = []
        
    def h1reset(self):
        
        self.current_bet = 0
        
        self.all_cards1 = []
        
    def h2reset(self):
        
        self.current_bet2 = 0
        
        self.all_cards2 = []

# %%
def p1total():
    
    global total
    
    total = 0
    
    for card in player1.all_cards1:
        
        total += card.value
        
        
    return total

# %%
def p1total2():
    
    global total2
    total2 = 0
    
    for card in player1.all_cards2:
        
        total2 += card.value
        
    return total2

# %%
def p2total():
    
    global player2total
    player2total = 0
    
    for card in player2.all_cards1:
        
        player2total += card.value
        
    return player2total

# %%
def p2total2():
    
    global player2total2
    player2total2 = 0
    
    for card in player2.all_cards2:
        
        player2total2 += card.value
        
    return player2total2

# %%
def p3total():
    
    global player3total
    player3total = 0
    
    for card in player3.all_cards1:
        
        player3total += card.value
        
    return player3total

# %%
def p3total2():
    
    global player3total2
    player3total2 = 0
    
    for card in player3.all_cards2:
        
        player3total2 += card.value
        
    return player3total2

# %%
def hit():
    
    choice = ""
    change = 0
    total = 0
    total2 = 0
    
    def p1total():
        
        global total
        total = 0

        for card in player1.all_cards1:

            total += card.value

        return total
                            
    player1.all_cards1.append(new_deck.deal_one())

    print(f'You now have {player1.all_cards1}')
    
    for card in player1.all_cards1:
                            
        if card.rank == "Ace":
            print("You have an Ace!")
                            
            while change not in [1,11]:

                change = input("Would you like to keep it 11, or make it a 1?")
                
                if change.isdigit() == False:
                    change = "choose again"
                else:
                    change = int(change)

                if change not in [1,11]:

                    print("Please choose 1 or 11")

                if change in [1,11]:

                    card.value = change

    total = p1total()

    print(f'The value of your cards is {total}.')

    if total == 21:
        print(f'{player1.name}, thats blackjack!')
        player1.cash_in(player1.current_bet*2)
        player1.h1reset()
        player1turn = False
        

    elif total > 21:
        print(f'{player1.name}, you bust!')
        player1.cash_out(player1.current_bet)
        player1.h1reset()
        player1turn = False
              
    elif total < 21:
        player1turn = True
              
    return player1turn

# %%
def secondHit():
    
    choice = ""
    change = 0
    total = 0
    total2 = 0
    
    def p1total2():
    
        global total2
        total2 = 0

        for card in player1.all_cards2:

            total2 += card.value

        return total2
                            
    player1.all_cards2.append(new_deck.deal_one())

    print(f'You now have {player1.all_cards2}')
    
    for card in player1.all_cards2:
                            
        if card.rank == "Ace":
            print("You have an Ace!")
                            
            while change not in [1,11]:

                change = input("Would you like to keep it 11, or make it a 1?")
                
                if change.isdigit() == False:
                    change = "choose again"
                else:
                    change = int(change)

                if change not in [1,11]:

                    print("Please choose 1 or 11")

                if change in [1,11]:

                    card.value = change

    total2 = p1total2()

    print(f'The value of your cards is {total2}.')

    if total2 == 21:
        print(f'{player1.name}, thats blackjack!')
        player1.cash_in(player1.current_bet2*2)
        player1.h2reset()
        player1turn = False
        

    elif total2 > 21:
        print(f'{player1.name}, you bust!')
        player1.cash_out(player1.current_bet2)
        player1.h2reset()
        player1turn = False
              
    elif total2 < 21:
        player1turn = True
              
    return player1turn

# %%
def hit2():
    
    choice = ""
    change = 0
    player2total = 0
    player2total2 = 0
    
    def p2total():
    
        global player2total
        player2total = 0

        for card in player2.all_cards1:

            player2total += card.value

        return player2total
                            
    player2.all_cards1.append(new_deck.deal_one())

    print(f'You now have {player2.all_cards1}')
    
    for card in player2.all_cards1:
                            
        if card.rank == "Ace":
            print("You have an Ace!")
                            
            while change not in [1,11]:

                change = input("Would you like to keep it 11, or make it a 1?")
                
                if change.isdigit() == False:
                    change = "choose again"
                else:
                    change = int(change)

                if change not in [1,11]:

                    print("Please choose 1 or 11")

                if change in [1,11]:

                    card.value = change
                
    player2total = p2total()

    print(f'The value of your cards is {player2total}.')

    if player2total == 21:
        print(f'{player2.name}, thats blackjack!')
        player2.cash_in(player2.current_bet*2)
        player2.h1reset()
        player2turn = False
        

    elif player2total > 21:
        print(f'{player2.name}, you bust!')
        player2.cash_out(player2.current_bet)
        player2.h1reset()
        player2turn = False
              
    elif player2total < 21:
        player2turn = True
              
    return player2turn

# %%
def secondHit2():
    
    choice = ""
    change = 0
    player2total = 0
    player2total2 = 0
    
    def p2total2():
    
        global player2total2
        player2total2 = 0

        for card in player2.all_cards2:

            player2total2 += card.value

        return player2total2
                            
    player2.all_cards2.append(new_deck.deal_one())

    print(f'You now have {player2.all_cards2}')
    
    for card in player2.all_cards2:
                        
        if card.rank == "Ace":
            print("You have an Ace!")
                            
            while change not in [1,11]:

                change = input("Would you like to keep it 11, or make it a 1?")
                
                if change.isdigit() == False:
                    change = "choose again"
                else:
                    change = int(change)

                if change not in [1,11]:

                    print("Please choose 1 or 11")

                if change in [1,11]:

                    card.value = change
                    
    player2total2 = p2total2()

    print(f'The value of your cards is {player2total2}.')

    if player2total2 == 21:
        print(f'{player2.name}, thats blackjack!')
        player2.cash_in(player2.current_bet2*2)
        player2.h2reset()
        player2turn = False
        

    elif player2total2 > 21:
        print(f'{player2.name}, you bust!')
        player2.cash_out(player2.current_bet2)
        player2.h2reset()
        player2turn = False
              
    elif player2total2 < 21:
        player2turn = True
              
    return player2turn

# %%
def hit3():
    
    choice = ""
    change = 0
    player3total = 0
    player3total2 = 0
    
    def p3total():
    
        global player3total
        player3total = 0

        for card in player3.all_cards1:

            player3total += card.value

        return player3total
                            
    player3.all_cards1.append(new_deck.deal_one())

    print(f'You now have {player3.all_cards1}')
    
    for card in player3.all_cards1:
                            
        if card.rank == "Ace":
            print("You have an Ace!")
                            
            while change not in [1,11]:

                change = input("Would you like to keep it 11, or make it a 1?")
                
                if change.isdigit() == False:
                    change = "choose again"
                else:
                    change = int(change)

                if change not in [1,11]:

                    print("Please choose 1 or 11")

                if change in [1,11]:

                    card.value = change

    player3total = p3total()

    print(f'The value of your cards is {player3total}.')

    if player3total == 21:
        print(f'{player3.name}, thats blackjack!')
        player3.cash_in(player3.current_bet*2)
        player3.h1reset()
        player3turn = False
        

    elif player3total > 21:
        print(f'{player3.name}, you bust!')
        player3.cash_out(player3.current_bet)
        player3.h1reset()
        player3turn = False
              
    elif player3total < 21:
        player3turn = True
              
    return player3turn

# %%
def secondHit3():
    
    choice = ""
    change = 0
    player3total = 0
    player3total2 = 0
    
    def p3total2():
    
        global player3total2
        player3total2 = 0

        for card in player3.all_cards2:

            player3total2 += card.value

        return player3total2
                            
    player3.all_cards2.append(new_deck.deal_one())

    print(f'You now have {player3.all_cards2}')
    
    for card in player1.all_cards2:
                            
        if card.rank == "Ace":
            print("You have an Ace!")

            while change not in [1,11]:

                change = input("Would you like to keep it 11, or make it a 1?")
                
                if change.isdigit() == False:
                    change = "choose again"
                else:
                    change = int(change)

                if change not in [1,11]:

                    print("Please choose 1 or 11")

                if change in [1,11]:

                    card.value = change
            
    player3total2 = p3total2()

    print(f'The value of your cards is {player3total2}.')

    if player3total2 == 21:
        print(f'{player3.name}, thats blackjack!')
        player3.cash_in(player3.current_bet2*2)
        player3.h2reset()
        player3turn = False
        

    elif player3total2 > 21:
        print(f'{player3.name}, you bust!')
        player3.cash_out(player3.current_bet2)
        player3.h2reset()
        player3turn = False
              
    elif player3total2 < 21:
        player3turn = True
              
    return player3turn

# %%
def dealerHit():
                            
    dealertotal = 0

    me.all_cards1.append(new_deck.deal_one())

    for cards in me.all_cards1:

        dealertotal += card.value

    
    return dealertotal

# %%
print("Welcome to BlackJack!")
print("Just two rules: you must bring at least 25 dollars to the table, and if you lose all your money, you're out!")

while True:
    #We're determing whether or not to start the game
    game_on = False

    while game_on != "yes":

        game_on = input("Are you ready to play?")

        game_on = game_on.lower()

    if game_on == "yes":
        game_on = True
    
    while game_on:
        #We're setting up the player names and bank accounts
        print("Great! Let's begin.")
        
        bank1, bank2, bank3 = -1,-1,-1
        
        while bank1 not in range(25, 1000000):

            name1 = input("Player 1, what is your name?")
            bank1 = input("And how much are you bringing to the table?")
            
            if bank1.isdigit() == False:
                bank1 = "choose again"
            else:
                bank1 = int(bank1)

        player1 = Player(name1,bank1)
        player1turn = True
        
        while bank2 not in range(25, 1000000):

            name2 = input("Player 2, what is your name?")
            bank2 = input("And how much are you bringing to the table?")
            
            if bank2.isdigit() == False:
                bank2 = "choose again"
            else:
                bank2 = int(bank2)

        player2 = Player(name2,bank2)
        player2turn = True
        
        while bank3 not in range(25, 1000000):
            
            name3 = input("Player 3, what is your name?")
            bank3 = input("And how much are you bringing to the table?")
            
            if bank3.isdigit() == False:
                bank3 = "choose again"
            else:
                bank3 = int(bank3)
            

        player3 = Player(name3,bank3)
        player3turn = True

        me = Player("Dealer",1000000)
        myturn = True
        playing = True

        while playing:
                #The game begins, while playing, we get the bets for each player for this
                #round. If they walked after the last round or if their total balance
                #is less than 25, they're out of the game. 
                new_deck = Deck()
                new_deck.shuffle()
                
                bet1, bet2, bet3 = -1,-1,-1
                
                if player1turn == True:
                    player1.h1reset()
                    if player1.balance < 25:
                        player1turn = False
                        print(f'{player1.name} is out!')
                        
                if player1turn == True:    
                    while bet1 not in range(25, player1.balance + 1):

                        bet1 = input(f'{player1.name}, what is your bet?')

                        if bet1.isdigit() == False:
                            bet1 = "choose again"
                        else:
                            bet1 = int(bet1)

                        if bet1 not in range(25, player1.balance + 1):

                            print("Please choose a number between 25 and your balance")

                    player1.current_bet = bet1
                    print(f'{player1.name}s bet is {bet1}')
                
                if player2turn == True:
                    player2.h1reset()
                    if player2.balance < 25:
                        player2turn = False
                        print(f'{player2.name} is out!')
                
                if player2turn == True:
                    while bet2 not in range(25, player2.balance + 1):

                        bet2 = input(f'{player2.name}, what is your bet?')
                        
                        if bet2.isdigit() == False:
                            bet2 = "choose again"
                        else:
                            bet2 = int(bet2)

                        if bet2 not in range(25, player2.balance + 1):

                            print("Please choose a number between 25 and your balance")

                    player2.current_bet = bet2
                    print(f'{player2.name}s bet is {bet2}')
                
                if player3turn == True:
                    player3.h1reset()
                    if player3.balance < 25:
                        player3turn = False
                        print(f'{player3.name} is out!')
                
                if player3turn == True:
                    while bet3 not in range(25, player3.balance + 1):

                        bet3 = input(f'{player3.name}, what is your bet?')
                        
                        if bet3.isdigit() == False:
                            bet3 = "choose again"
                        else:
                            bet3 = int(bet3)

                        if bet3 not in range(25, player3.balance + 1):

                            print("Please choose a number between 25 and your balance")

                    player3.current_bet = bet3
                    print(f'{player3.name}s bet is {bet3}')
                      
                print("Now here are your cards...")
                #This loop appends two cards to each player and the dealers hands.       
                for x in range(2):
                    player1.all_cards1.append(new_deck.deal_one())
                    player2.all_cards1.append(new_deck.deal_one())
                    player3.all_cards1.append(new_deck.deal_one())  
                    me.all_cards1.append(new_deck.deal_one())
                #It is now player 1's turn.      
                while player1turn:
                      
                    choice = ""
                    change = 0
                    total = 0
                    total2 = 0
                
                    print(f'Its your turn, {player1.name}!')
                    print(f'Your starting balance is: {player1.balance}.')
                    print(f'Your hand: {player1.all_cards1}')
                    print(f'Your bet: {player1.current_bet}')
                    print(f'Heres my face card: {me.all_cards1[0]}')
                    #If one of their initial cards is an ace, we let them choose between
                    #1 and 11 for the value of the card
                    for card in player1.all_cards1:
                            
                        if card.rank == "Ace":
                            print("You have an Ace!")
                            
                            while change not in [1,11]:
                                        
                                change = input("Would you like to keep it 11, or make it a 1?")
                                
                                if change.isdigit() == False:
                                    change = "choose again"
                                else:
                                    change = int(change)
                                        
                                if change not in [1,11]:

                                    print("Please choose 1 or 11")

                                if change in [1,11]:

                                    card.value = change
                    #We calculate the total value of the cards in the players hand                   
                    total = p1total()
                            
                    if total == 21:
                        print(f'{player1.name}, thats blackjack!')
                        player1.cash_in(player1.current_bet*2)
                        player1.h1reset()
                        print(f'Your final balance is: {player1.balance}.')
                        player1turn = False
                        break
                                    
                    elif total > 21:
                        player1.all_cards1[0].value = 1
                        
                    total = p1total()
                                  
                    print(f'The value of your cards is {total}.')
                    #The initial choice to either hit, double down, split, or stay
                    while choice not in ["hit","double down","split","stay"]:
                      
                        choice = input("What would you like to do? Hit, double down, split, or stay?")
                            
                        choice = choice.lower()
                        
                        if choice == "double down":
                            
                            if player1.balance < player1.current_bet * 2:
                                
                                print("Not enough funds!")
                                
                                choice = "choose again"
                        
                        if choice == "split":
                            
                            if player1.all_cards1[0].value != player1.all_cards1[1].value:
                                
                                choice = "choose again"
                                
                            if player1.balance < player1.current_bet * 2:
                                
                                print("Not enough funds!")
                                
                                choice = "choose again"
                            
                        if choice not in ["hit","double down","split","stay"]:
                            
                            print("Please choose again.")
                            
                    if choice == "stay":
                        print(f'Your final balance is: {player1.balance}.')
                        player1turn = False
                        break
                    
                    if choice == "hit":
                        
                        while player1turn == True:
                            
                            player1turn = hit()

                            if player1turn == False:

                                break

                            else:

                                print(f'Your hand: {player1.all_cards1}')
                                print(f'Your bet: {player1.current_bet}')
                                print(f'Heres my face card: {me.all_cards1[0]}')
                                
                                choice = ""

                                while choice not in ["hit","stay"]:

                                    choice = input("Hit or stay?")
                                    
                                    choice = choice.lower()

                                    if choice not in ["hit","stay"]:

                                        print("Please choose again!")

                                    if choice == "hit":

                                        break
                                    elif choice == "stay":
                                        
                                        print(f'The value of your cards is {total}')

                                        player1turn = False
                    
                        print(f'Your final balance is: {player1.balance}.')
                        break
                    #If the player doubles down, their bet is increased by 2x, and they
                    #are allowed 1 more card, which they can decline.
                    if choice == "double down":
                            
                        player1.current_bet *= 2
                                    
                        print(f'Your hand: {player1.all_cards1}')
                        print(f'Your bet: {player1.current_bet}')
                        print(f'The value of your cards is {total}.')
                        print(f'Heres my face card: {me.all_cards1[0]}')
                        
                        choice = ""

                        while choice not in ["hit","stay"]:

                            choice = input("Hit or stay?")
                                    
                            choice = choice.lower()

                            if choice not in ["hit","stay"]:

                                print("Please choose again!")

                            if choice == "hit":

                                player1turn = hit()
                                
                                player1turn = False
                            
                            elif choice == "stay":

                                player1turn = False
                                     
                          
                        print(f'Your hand: {player1.all_cards1}')
                        print(f'Your bet: {player1.current_bet}')
                        print(f'The value of your cards is {total}.')
                        print(f'Your final balance is: {player1.balance}.')
                        
                        break
                    #If the choice is split, they now split their single hand into two 
                    #hands, place an equal bet on each hands, and receive one extra card 
                    #for each hand. 
                    if choice == "split":
                          
                        player1.all_cards2.append(player1.all_cards1.pop())
                                
                        player1.all_cards1.append(new_deck.deal_one())
                                
                        player1.all_cards2.append(new_deck.deal_one())
                                
                        player1.current_bet2 = player1.current_bet
                        
                        for card in player1.all_cards1:
                            
                            if card.rank == "Ace":
                                print("You have an Ace!")

                                while change not in [1,11]:

                                    change = input("Would you like to keep it 11, or make it a 1?")
                                    
                                    if change.isdigit() == False:
                                        change = "choose again"
                                    else:
                                        change = int(change)

                                    if change not in [1,11]:

                                        print("Please choose 1 or 11")

                                    if change in [1,11]:

                                        card.value = change

                        for card in player1.all_cards2:
                            
                            if card.rank == "Ace":
                                print("You have an Ace!")

                                while change not in [1,11]:

                                    change = input("Would you like to keep it 11, or make it a 1?")
                                    
                                    if change.isdigit() == False:
                                        change = "choose again"
                                    else:
                                        change = int(change)

                                    if change not in [1,11]:

                                        print("Please choose 1 or 11")

                                    if change in [1,11]:

                                        card.value = change
                                
                        total = p1total()
                                
                        total2 = p1total2()
                          
                        print(f'Your hands: {player1.all_cards1} and {player1.all_cards2}')
                        print(f'Your bets: {player1.current_bet} and {player1.current_bet2}')
                        print(f'The value of your cards is {total} and {total2}.')  
                        print(f'Heres my face card: {me.all_cards1[0]}')
                        
                        if total == 21:
                            print(f'{player1.name}, thats blackjack!')
                            player1.cash_in(player1.current_bet*2)
                            player1.h1reset()
                            
                            
                        if total2 == 21:
                            print(f'{player1.name}, thats blackjack!')
                            player1.cash_in(player1.current_bet2*2)
                            player1.h2reset()
                            
                            
                        if total == 21 and total2 == 21:
                            print(f'Your final balance is: {player1.balance}.')
                            player1.reset()
                            player1turn = False
                            break
                            
                        if total > 21:
                            player1.all_cards1[0].value = 1
                         
                        if total2 > 21:
                            player1.all_cards2[0].value = 1
                            
                        total = p1total()
                                
                        total2 = p1total2()
                                
                        print(f'The value of your cards is now {total} and {total2}.')
                            
                        #After they split, we have already determined if they blackjacked
                        #or if we reduced one or both of their aces to 1. They now have
                        #The option to double down.
                        if player1.balance >= player1.current_bet * 2:
                            while choice not in ["one","two","both","neither"]:
                                print(f'{player1.all_cards1},{player1.all_cards2}')
                                print(f'{player1.current_bet},{player1.current_bet2}.')

                                choice = input("Which hand would you like to double down? one, two, both, or neither?")

                                choice = choice.lower()
                                if choice not in ["one","two","both","neither"]:

                                    print("Please choose again, one, two, both or neither")

                                if choice == "one":

                                    player1.current_bet*=2
                                if choice == "two":
                                    player1.current_bet2*=2
                                if choice == "both":
                                    if player1.balance >= player1.current_bet*4:
                                        player1.current_bet*=2
                                        player1.current_bet2*=2
                                    else:
                                        print("Not enough funds")
                                        choice = "choose again"
                        #This is just checking if either of their hands are still in play
                        #and if so, they can choose to hit on either of those hands. 
                        if total < 21:
                            
                            print(f'Your first hand: {player1.all_cards1}')
                            print(f'Your first bet: {player1.current_bet}')
                            print(f'The value of your first hand is {total}')  
                            print(f'Heres my face card: {me.all_cards1[0]}')
                            
                            choice = ""

                            while choice not in ["hit","stay"]:

                                choice = input("Hit or stay?")

                                if choice not in ["hit","stay"]:

                                    print("Please choose again!")

                                if choice == "hit":

                                    player1turn = hit()
                                    
                                    player1turn = False
                                
                                elif choice == "stay":

                                    player1turn = False
                    
                        if total2 < 21:
                            
                            print(f'Your second hand: {player1.all_cards2}')
                            print(f'Your second bet: {player1.current_bet2}')
                            print(f'The value of your second hand is {total2}')  
                            print(f'Heres my face card: {me.all_cards1[0]}')
                            
                            choice = ""

                            while choice not in ["hit","stay"]:

                                choice = input("Hit or stay?")

                                if choice not in ["hit","stay"]:

                                    print("Please choose again!")

                                if choice == "hit":

                                    player1turn = secondHit()
                                    
                                    player1turn = False
                                        
                                    
                                
                                elif choice == "stay":

                                    player1turn = False
                        
                        total = p1total()
                        total2 = p1total2()
        
                        print(f'{player1.name}s hands: {player1.all_cards1} and {player1.all_cards2}')
                        print(f'{player1.name}s bets: {player1.current_bet} and {player1.current_bet2}')
                        print(f'The value of your cards is {total} and {total2}.')
                        print(f'Your final balance is: {player1.balance}.')
                        
                        break
                #It is now player 2s turn        
                while player2turn:
                      
                    choice = ""
                    change = 0
                    player2total = 0
                    player2total2 = 0
                      
                    print(f'Its your turn, {player2.name}!')
                    print(f'Your starting balance is: {player2.balance}.')
                    print(f'Your hand: {player2.all_cards1}')
                    print(f'Your bet: {player2.current_bet}')
                    print(f'Heres my face card: {me.all_cards1[0]}')
                    #If there's an ace, we allow an opportunity to change it to a 1 or 11
                    for card in player2.all_cards1:
                            
                        if card.rank == "Ace":
                            print("You have an Ace!")

                            while change not in [1,11]:

                                change = input("Would you like to keep it 11, or make it a 1?")
                                      
                                if change.isdigit() == False:
                                    change = "choose again"
                                else:
                                    change = int(change)

                                if change not in [1,11]:

                                    print("Please choose 1 or 11")

                                if change in [1,11]:

                                    card.value = change
                                    
                    player2total = p2total()
                            
                    if player2total == 21:
                        print(f'{player2.name}, thats blackjack!')
                        player2.cash_in(player2.current_bet*2)
                        player2.h1reset()
                        print(f'Your final balance is: {player2.balance}.')
                        player2turn = False
                        break
                                    
                    elif player2total > 21:
                        player2.all_cards1[0].value = 1
                        
                    player2total = p2total()
                                  
                    print(f'The value of your cards is {player2total}.')
                    #Now allowing the initial choice to hit, double down, split, or stay
                    while choice not in ["hit","double down","split","stay"]:
                      
                        choice = input("What would you like to do? Hit, double down, split, or stay?")
                            
                        choice = choice.lower()
                                      
                        if choice == "double down":
                            
                            if player2.balance < player2.current_bet * 2:
                                
                                print("Not enough funds!")
                                
                                choice = "choose again"
                        
                        if choice == "split":
                            
                            if player2.all_cards1[0].value != player2.all_cards1[1].value:
                                
                                choice = "Choose again"
                                
                            if player2.balance < player2.current_bet * 2:
                                
                                print("Not enough funds!")
                                
                                choice = "choose again"
                            
                        if choice not in ["hit","double down","split","stay"]:
                            
                            print("Please choose again.")
                            
                    if choice == "stay":
                        print(f'Your final balance is: {player2.balance}.')
                        player2turn = False
                        break
                     #"HIT" begins a loop to continue asking hit or stay until the player
                    #either busts, blackjacks, or stays
                    if choice == "hit":
                        
                        while player2turn == True:
                            
                            player2turn = hit2()

                            if player2turn == False:

                                break

                            else:

                                print(f'Your hand: {player2.all_cards1}')
                                print(f'Your bet: {player2.current_bet}')
                                print(f'Heres my face card: {me.all_cards1[0]}')
                                
                                choice = ""

                                while choice not in ["hit","stay"]:

                                    choice = input("Hit or stay?")
                                    
                                    choice = choice.lower()

                                    if choice not in ["hit","stay"]:

                                        print("Please choose again!")

                                    if choice == "hit":

                                        break
                                    elif choice == "stay":
                                    
                                        print(f'The value of your cards is {player2total}')

                                        player2turn = False
                        print(f'Your final balance is: {player2.balance}.')
                        break
                    #"Double down asks if the player wants to double their bet, and they
                    #get one extra card."                    
                    if choice == "double down":
                            
                        player2.current_bet *= 2
                                    
                        print(f'Your hand: {player2.all_cards1}')
                        print(f'Your bet: {player2.current_bet}')
                        print(f'The value of your cards is {player2total}.')
                        print(f'Heres my face card: {me.all_cards1[0]}')
                        
                        choice = ""

                        while choice not in ["hit","stay"]:

                            choice = input("Hit or stay?")
                                    
                            choice = choice.lower()

                            if choice not in ["hit","stay"]:

                                print("Please choose again!")

                            if choice == "hit":

                                player2turn = hit2()
                                
                                player2turn = False
                            
                            elif choice == "stay":

                                player2turn = False
                                
                        player2total = p2total()           
                          
                        print(f'Your hand: {player2.all_cards1}')
                        print(f'Your bet: {player2.current_bet}')
                        print(f'The value of your cards is {player2total}.')
                        print(f'Your final balance is: {player2.balance}.')
                        
                        break
                    #If the choice is split, they now split their single hand into two 
                    #hands, place an equal bet on each hands, and receive one extra card 
                    #for each hand.             
                    if choice == "split":
                        
                        
                          
                        player2.all_cards2.append(player2.all_cards1.pop())
                                
                        player2.all_cards1.append(new_deck.deal_one())
                                
                        player2.all_cards2.append(new_deck.deal_one())
                                
                        player2.current_bet2 = player2.current_bet
                        
                        for card in player2.all_cards1:
                            
                            if card.rank == "Ace":
                                print("You have an Ace!")

                                while change not in [1,11]:

                                    change = input("Would you like to keep it 11, or make it a 1?")
                                      
                                    if change.isdigit() == False:
                                        change = "choose again"
                                    else:
                                        change = int(change)

                                    if change not in [1,11]:

                                        print("Please choose 1 or 11")

                                    if change in [1,11]:

                                        card.value = change
                                    
                        for card in player2.all_cards2:
                            
                            if card.rank == "Ace":
                                print("You have an Ace!")

                                while change not in [1,11]:

                                    change = input("Would you like to keep it 11, or make it a 1?")
                                      
                                    if change.isdigit() == False:
                                        change = "choose again"
                                    else:
                                        change = int(change)

                                    if change not in [1,11]:

                                        print("Please choose 1 or 11")

                                    if change in [1,11]:

                                        card.value = change
                                
                        player2total = p2total()
                        player2total2 = p2total2()
                          
                        print(f'Your hands: {player2.all_cards1} and {player2.all_cards2}')
                        print(f'Your bets: {player2.current_bet} and {player2.current_bet2}')
                        print(f'The value of your cards is {player2total} and {player2total2}.')  
                        print(f'Heres my face card: {me.all_cards1[0]}')
                        
                        if total == 21:
                            print(f'{player2.name}, thats blackjack!')
                            player2.cash_in(player2.current_bet*2)
                            player2.h1reset()
                            
                        if total2 == 21:
                            print(f'{player2.name}, thats blackjack!')
                            player2.cash_in(player2.current_bet2*2)
                            player2.h2reset()
                            
                        if total == 21 and total2 == 21:
                            print(f'Your final balance is: {player2.balance}.')
                            player2.reset()
                            player2turn = False
                            break
                            
                        if total > 21:
                            player2.all_cards1[0].value = 1
                         
                        if total2 > 21:
                            player2.all_cards2[0].value = 1
                            
                        player2total = p2total()
                        player2total2 = p2total2()
                                
                        print(f'The value of your cards is now {player2total} and {player2total2}.')
                            
                
                        if player2.balance >= player2.current_bet * 2:
                            while choice not in ["one","two","both","neither"]:
                                print(f'{player2.all_cards1},{player2.all_cards2}')
                                print(f'{player2.current_bet},{player2.current_bet2}.')

                                choice = input("Which hand would you like to double down? one, two, both, or neither?")

                                choice = choice.lower()
                                if choice not in ["one","two","both","neither"]:

                                    print("Please choose again, one, two, both or neither")

                                if choice == "one":

                                    player2.current_bet*=2
                                if choice == "two":
                                    player2.current_bet2*=2
                                if choice == "both":
                                    if player2.balance >= player2.current_bet*4:
                                        player2.current_bet*=2
                                        player2.current_bet2*=2
                                    else:
                                        print("Not enough funds")
                                        choice = "choose again"
                            
                       #Again, check here if either hand is still in play         
                        if player2total < 21:
                            
                            print(f'Your first hand: {player2.all_cards1}')
                            print(f'Your first bet: {player2.current_bet}')
                            print(f'The value of your first hand is {total}')  
                            print(f'Heres my face card: {me.all_cards1[0]}')
                            
                            choice = ""

                            while choice not in ["hit","stay"]:

                                choice = input("Hit or stay?")

                                if choice not in ["hit","stay"]:

                                    print("Please choose again!")

                                if choice == "hit":

                                    player2turn = hit2()
                                    
                                    player2turn = False
                                
                                elif choice == "stay":

                                    player2turn = False
                    
                        if player2total2 < 21:
                            
                            print(f'Your second hand: {player2.all_cards2}')
                            print(f'Your second bet: {player2.current_bet2}')
                            print(f'The value of your second hand is {player2total2}')  
                            print(f'Heres my face card: {me.all_cards1[0]}')
                            
                            choice = ""

                            while choice not in ["hit","stay"]:

                                choice = input("Hit or stay?")

                                if choice not in ["hit","stay"]:

                                    print("Please choose again!")

                                if choice == "hit":

                                    player2turn = secondHit2()
                                    
                                    player2turn = False
                                        
                                    
                                
                                elif choice == "stay":

                                    player2turn = False

                                    
                        player2total = p2total()
                        player2total2 = p2total2()
                       
                          
                        print(f'{player2.name}s hands: {player2.all_cards1} and {player2.all_cards2}')
                        print(f'{player2.name}s bets: {player2.current_bet} and {player2.current_bet2}')
                        print(f'The value of your cards is {player2total} and {player2total2}.')
                        print(f'Your final balance is: {player2.balance}.')
                        
                        break
                        
                while player3turn:
                      
                    choice = ""
                    change = 0
                    player3total = 0
                    player3total2 = 0
                      
                    print(f'Its your turn, {player3.name}!')
                    print(f'Your starting balance is: {player3.balance}.')
                    print(f'Your hand: {player3.all_cards1}')
                    print(f'Your bet: {player3.current_bet}')
                    print(f'Heres my face card: {me.all_cards1[0]}')
                    #Allowing player 3 to choose 1 or 11 for their ace
                    for card in player3.all_cards1:
                            
                        if card.rank == "Ace":
                            print("You have an Ace!")

                            while change not in [1,11]:

                                change = input("Would you like to keep it 11, or make it a 1?")
                                      
                                if change.isdigit() == False:
                                    change = "choose again"
                                else:
                                    change = int(change)

                                if change not in [1,11]:

                                    print("Please choose 1 or 11")

                                if change in [1,11]:

                                    card.value = change
                                    
                    player3total = p3total()
                            
                    if player3total == 21:
                        print(f'{player3.name}, thats blackjack!')
                        player3.cash_in(player3.current_bet*2)
                        print(f'Your final balance is: {player3.balance}.')
                        player3.h1reset()
                        player3turn = False
                        break
                                    
                    elif player3total > 21:
                        player3.all_cards1[0].value = 1
                        
                    player3total = p3total()
                                  
                    print(f'The value of your cards is {player3total}.')
                    #Player can hit, double down, split, or stay
                    while choice not in ["hit","double down","split","stay"]:
                      
                        choice = input("What would you like to do? Hit, double down, split, or stay?")
                            
                        choice = choice.lower()
                                      
                        if choice == "double down":
                            
                            if player3.balance < player3.current_bet * 2:
                                
                                print("Not enough funds!")
                                
                                choice = "choose again"
                        
                        if choice == "split":
                            
                            if player3.all_cards1[0].value != player3.all_cards1[1].value:
                                
                                choice = "choose again"
                                
                            if player3.balance < player3.current_bet * 2:
                                
                                print("Not enough funds!")
                                
                                choice = "choose again"
                            
                        if choice not in ["hit","double down","split","stay"]:
                            
                            print("Please choose again.")
                            
                    if choice == "stay":
                        print(f'Your final balance is: {player3.balance}.')
                        player3turn = False
                        break
                        
                    #Hit begins loop to look for either bust, blackjack or stay        
                    if choice == "hit":
                        
                        while player3turn == True:
                            
                            player3turn = hit3()

                            if player3turn == False:

                                break

                            else:

                                print(f'Your hand: {player3.all_cards1}')
                                print(f'Your bet: {player3.current_bet}')
                                print(f'The value of your cards is {player3total}.')

                                choice = ""

                                while choice not in ["hit","stay"]:

                                    choice = input("Hit or stay?")
                                    
                                    choice = choice.lower()

                                    if choice not in ["hit","stay"]:

                                        print("Please choose again!")

                                    if choice == "hit":

                                        break
                                    elif choice == "stay":
                                
                                        print(f'The value of your cards is {player3total}')

                                        player3turn = False
                        print(f'Your final balance is: {player3.balance}.')
                        break
                    #Player 3 can double their bet, and receive one more card                    
                    if choice == "double down":
                            
                        player3.current_bet *= 2
                                    
                        print(f'Your hand: {player3.all_cards1}')
                        print(f'Your bet: {player3.current_bet}')
                        print(f'The value of your cards is {player3total}.')
                        print(f'Heres my face card: {me.all_cards1[0]}')
                        
                        choice = ""

                        while choice not in ["hit","stay"]:

                            choice = input("Hit or stay?")
                                    
                            choice = choice.lower()

                            if choice not in ["hit","stay"]:

                                print("Please choose again!")

                            if choice == "hit":

                                player3turn = hit3()
                                
                                player3turn = False
                            
                            elif choice == "stay":

                                player3turn = False
                         
                          
                        print(f'Your hand: {player3.all_cards1}')
                        print(f'Your bet: {player3.current_bet}')
                        print(f'The value of your cards is: {player3total}')
                        print(f'Your final balance is: {player3.balance}.')
                        
                        break
                    #If the choice is split, they now split their single hand into two 
                    #hands, place an equal bet on each hands, and receive one extra card 
                    #for each hand.            
                    if choice == "split":
                          
                        player3.all_cards2.append(player3.all_cards1.pop())
                                
                        player3.all_cards1.append(new_deck.deal_one())
                                
                        player3.all_cards2.append(new_deck.deal_one())
                                
                        player3.current_bet2 = player3.current_bet
                        
                        for card in player3.all_cards1:
                            
                            if card.rank == "Ace":
                                print("You have an Ace!")

                                while change not in [1,11]:

                                    change = input("Would you like to keep it 11, or make it a 1?")

                                    if change.isdigit() == False:
                                        change = "choose again"
                                    else:
                                        change = int(change)

                                    if change not in [1,11]:

                                        print("Please choose 1 or 11")

                                    if change in [1,11]:

                                        card.value = change
                        for card in player3.all_cards2:
                            
                            if card.rank == "Ace":
                                print("You have an Ace!")

                                while change not in [1,11]:

                                    change = input("Would you like to keep it 11, or make it a 1?")

                                    if change.isdigit() == False:
                                        change = "choose again"
                                    else:
                                        change = int(change)

                                    if change not in [1,11]:

                                        print("Please choose 1 or 11")

                                    if change in [1,11]:

                                        card.value = change
                                
                        player3total = p3total()
                        player3total2 = p3total2()
                          
                        print(f'Your hands: {player3.all_cards1} and {player3.all_cards2}')
                        print(f'Your bets: {player3.current_bet} and {player3.current_bet2}')
                        print(f'The value of your cards is {player3total} and {player3total2}.')  
                        print(f'Heres my face card: {me.all_cards1[0]}')
                        
                        if player3total == 21:
                            print(f'{player1.name}, thats blackjack!')
                            player3.cash_in(player3.current_bet*2)
                            player3.h1reset()
                            
                        if player3total2 == 21:
                            print(f'{player1.name}, thats blackjack!')
                            player3.cash_in(player3.current_bet2*2)
                            player3.h2reset()
                            
                        if player3total == 21 and player3total2 == 21:
                            print(f'Your final balance is: {player1.balance}.')
                            player3.reset()
                            player3turn = False
                            break
                            
                        if player3total > 21:
                            player3.all_cards1[0].value = 1
                         
                        if player3total2 > 21:
                            player3.all_cards2[0].value = 1
                            
                        player3total = p3total()
                        player3total2 = p3total2()
                        
                        print(f'The value of your cards is now {player3total} and {player3total2}.')
                            
                
                        if player3.balance >= player3.current_bet * 2:
                            while choice not in ["one","two","both","neither"]:
                                print(f'{player3.all_cards1},{player3.all_cards2}')
                                print(f'{player3.current_bet},{player3.current_bet2}.')

                                choice = input("Which hand would you like to double down? one, two, both, or neither?")

                                choice = choice.lower()
                                if choice not in ["one","two","both","neither"]:

                                    print("Please choose again, one, two, both or neither")

                                if choice == "one":

                                    player3.current_bet*=2
                                if choice == "two":
                                    player3.current_bet2*=2
                                if choice == "both":
                                    if player3.balance >= player3.current_bet*4:
                                        player3.current_bet*=2
                                        player3.current_bet2*=2
                                    else:
                                        print("Not enough funds")
                                        choice = "choose again"
                                
                        if player3total < 21:
                            
                            print(f'Your first hand: {player3.all_cards1}')
                            print(f'Your first bet: {player3.current_bet}')
                            print(f'The value of your first hand is {player3total}')  
                            print(f'Heres my face card: {me.all_cards1[0]}')
                            
                            choice = ""

                            while choice not in ["hit","stay"]:

                                choice = input("Hit or stay?")

                                if choice not in ["hit","stay"]:

                                    print("Please choose again!")

                                if choice == "hit":

                                    player3turn = hit3()
                                    
                                    player3turn = False
                                
                                elif choice == "stay":

                                    player3turn = False
                    
                        if player3total2 < 21:
                            
                            print(f'Your second hand: {player3.all_cards2}')
                            print(f'Your second bet: {player3.current_bet2}')
                            print(f'The value of your second hand is {player3total2}')  
                            print(f'Heres my face card: {me.all_cards1[0]}')
                            
                            choice = ""

                            while choice not in ["hit","stay"]:

                                choice = input("Hit or stay?")

                                if choice not in ["hit","stay"]:

                                    print("Please choose again!")

                                if choice == "hit":

                                    player3turn = secondHit3()
                                    
                                    player3turn = False
                                        
                                    
                                
                                elif choice == "stay":

                                    player3turn = False

                                    
                        
                        player3total = p3total()
                        player3total2 = p3total2()
                          
                        print(f'{player3.name}s hands: {player3.all_cards1} and {player3.all_cards2}')
                        print(f'{player3.name}s bets: {player3.current_bet} and {player3.current_bet2}')
                        print(f'The value of your cards is {player3total} and {player3total2}.')
                        print(f'Your final balance is: {player3.balance}.')
                        
                        break
                            
                while myturn:
                    
                    print("My turn! Here are my cards...")
                    
                    dealertotal = 0 
                    
                    for card in me.all_cards1:
                        
                        dealertotal += card.value
                    
                    while dealertotal < 17:
                    
                        dealertotal = 0

                        me.all_cards1.append(new_deck.deal_one())

                        for card in me.all_cards1:

                            dealertotal += card.value
                            
                    print(f'{me.all_cards1}.')
                        
                    if dealertotal >= 17:
                        
                        if dealertotal > 21:
                            
                            print(f'My total is {dealertotal}')
                            print("Looks like I busted!")
                            print("Everyone under 21 wins!")
                              
                            if player1.all_cards1 != [] and total <= 21:
                                print(f'{player1.name} wins {player1.current_bet*2} dollars!')
                                player1.cash_in(player1.current_bet*2)
                                player1.h1reset()
                              
                            if player1.all_cards2 != [] and total2 <= 21:
                                print(f'{player1.name} wins {player1.current_bet2*2} dollars!')
                                player1.cash_in(player1.current_bet2*2)
                                player1.h2reset()

                            if player2.all_cards1 != [] and player2total <= 21:
                                print(f'{player2.name} wins {player2.current_bet*2} dollars!')
                                player2.cash_in(player2.current_bet*2)
                                player2.h1reset()
                              
                            if player2.all_cards2 != [] and player2total2 <= 21:
                                print(f'{player2.name} wins {player2.current_bet2*2} dollars!')
                                player2.cash_in(player2.current_bet2*2)
                                player2.h2reset()
                              
                            if player3.all_cards1 != [] and player3total <= 21:
                                print(f'{player3.name} wins {player3.current_bet*2} dollars!')
                                player3.cash_in(player3.current_bet*2)
                                player3.h1reset()
                              
                            if player3.all_cards2 != [] and player3total2 <= 21:
                                print(f'{player3.name} wins {player3.current_bet2*2} dollars!')
                                player3.cash_in(player3.current_bet2*2)
                                player3.h2reset()

                        if dealertotal == 21:
                            
                            print(f'My total is {dealertotal}')
                            print("That's blackjack! If you don't have 21, you're out of luck!")
                              
                            if player1.all_cards1 != [] and total == 21:
                                print(f'{player1.name} wins {player1.current_bet*2} dollars!')
                                player1.cash_in(player1.current_bet*2)
                                player1.h1reset()
                              
                            if player1.all_cards1 != [] and total < 21:
                                print(f'{player1.name} lost {player1.current_bet} dollars!')
                                player1.cash_out(player1.current_bet)
                                player1.h1reset()

                            if player1.all_cards2 != [] and total2 == 21:
                                print(f'{player1.name} wins {player1.current_bet2*2} dollars!')
                                player1.cash_in(player1.current_bet2*2)
                                player1.h2reset()
                              
                            if player1.all_cards2 != [] and total2 < 21:
                                print(f'{player1.name} lost {player1.current_bet2} dollars!')
                                player1.cash_out(player1.current_bet)
                                player1.h1reset()
                              
                            if player2.all_cards1 != [] and player2total == 21:
                                print(f'{player2.name} wins {player2.current_bet*2} dollars!')
                                player2.cash_in(player2.current_bet*2)
                                player2.h1reset()
                              
                            if player2.all_cards1 != [] and player2total < 21:
                                print(f'{player2.name} lost {player1.current_bet} dollars!')
                                player2.cash_out(player2.current_bet)
                                player2.h1reset()
                              
                            if player2.all_cards2 != [] and player2total2 == 21:
                                print(f'{player2.name} wins {player2.current_bet2*2} dollars!')
                                player2.cash_in(player2.current_bet2*2)
                                player2.h2reset()

                            if player2.all_cards2 != [] and player2total2 < 21:
                                print(f'{player2.name} lost {player1.current_bet2} dollars!')
                                player2.cash_out(player2.current_bet2)
                                player2.h2reset()
                              
                            if player3.all_cards1 != [] and player3total == 21:
                                print(f'{player3.name} wins {player3.current_bet*2} dollars!')
                                player3.cash_in(player3.current_bet*2)
                                player3.h1reset()
                              
                            if player3.all_cards1 != [] and player3total < 21:
                                print(f'{player3.name} lost {player3.current_bet} dollars!')
                                player3.cash_out(player3.current_bet)
                                player3.h1reset()
                              
                            if player3.all_cards2 != [] and player3total2 == 21:
                                print(f'{player3.name} wins {player3.current_bet2*2} dollars!')
                                player3.cash_in(player3.current_bet*2)
                                player3.h2reset()
                              
                            if player3.all_cards2 != [] and player3total2 == 21:
                                print(f'{player3.name} lost {player3.current_bet2} dollars!')
                                player3.cash_out(player3.current_bet2)
                                player3.h2reset()

                        if dealertotal < 21:
                              
                            print("Let's see who beat me!")
                            print(f'My total is {dealertotal}')
                              
                            if player1.all_cards1 != [] and total >= dealertotal:
                                print(f'{player1.name} wins {player1.current_bet*2} dollars!')
                                player1.cash_in(player1.current_bet*2)
                                player1.h1reset()
                              
                            if player1.all_cards1 != [] and total < dealertotal:
                                print(f'{player1.name} lost {player1.current_bet} dollars!')
                                player1.cash_out(player1.current_bet)
                                player1.h1reset()
                              
                            if player1.all_cards2 != [] and total2 >= dealertotal:
                                print(f'{player1.name} wins {player1.current_bet2*2} dollars!')
                                player1.cash_in(player1.current_bet2*2)
                                player1.h2reset()
                              
                            if player1.all_cards2 != [] and total2 < dealertotal:
                                print(f'{player1.name} lost {player1.current_bet2} dollars!')
                                player1.cash_out(player1.current_bet2)
                                player1.h2reset()

                            if player2.all_cards1 != [] and player2total >= dealertotal:
                                print(f'{player2.name} wins {player2.current_bet*2} dollars!')
                                player2.cash_in(player2.current_bet*2)
                                player2.h1reset()

                            if player2.all_cards1 != [] and player2total < dealertotal:
                                print(f'{player2.name} lost {player2.current_bet} dollars!')
                                player2.cash_out(player2.current_bet)
                                player2.h1reset()

                            if player2.all_cards2 != [] and player2total2 >= dealertotal:
                                print(f'{player2.name} wins {player2.current_bet2*2} dollars!')
                                player2.cash_in(player2.current_bet2*2)
                                player2.h2reset()
                            
                            if player2.all_cards2 != [] and player2total2 < dealertotal:
                                print(f'{player2.name} lost {player2.current_bet2} dollars!')
                                player2.cash_out(player2.current_bet2)
                                player2.h2reset()
                              
                            if player3.all_cards1 != [] and player3total >= dealertotal:
                                print(f'{player3.name} wins {player3.current_bet*2} dollars!')
                                player3.cash_in(player3.current_bet*2)
                                player3.h1reset()
                              
                            if player3.all_cards1 != [] and player3total < dealertotal:
                                print(f'{player3.name} lost {player3.current_bet} dollars!')
                                player3.cash_out(player3.current_bet)
                                player3.h1reset()
                              
                            if player3.all_cards2 != [] and player3total2 >= dealertotal:
                                print(f'{player3.name} wins {player3.current_bet2*2} dollars!')
                                player3.cash_in(player3.current_bet*2)
                                player3.h2reset()
                              
                            if player3.all_cards2 != [] and player3total2 < dealertotal:
                                print(f'{player3.name} lost {player3.current_bet2} dollars!')
                                player3.cash_out(player3.current_bet)
                                player3.h2reset()
                                    
                    me.reset()        
                    print("This round is over!")
                    print(f'Everyone, here are your final balances: {player1.name} has {player1.balance} dollars, {player2.name} has {player2.balance} dollars, and {player3.name} has {player3.balance} dollars.')
                    
                    player1turn=""
                    player2turn=""
                    player3turn=""
                                    
                    while player1turn not in ["yes","no"]:
                    
                        player1turn = input(f'{player1.name}, do you wish to keep playing? yes or no')
                                    
                        player1turn = player1turn.lower()
                                    
                    while player2turn not in ["yes","no"]:
                    
                        player2turn = input(f'{player2.name}, do you wish to keep playing? yes or no')
                                    
                        player2turn = player2turn.lower()
                                    
                    while player3turn not in ["yes","no"]:
                    
                        player3turn = input(f'{player3.name}, do you wish to keep playing? yes or no')
                                    
                        player3turn = player3turn.lower()
                                    
                    if player1turn == "yes":
                                    
                        player1turn = True
                                    
                    elif player1turn == "no":
                                    
                        player1turn = False
                                    
                    if player2turn == "yes":
                                    
                        player2turn = True
                                    
                    elif player2turn == "no":
                                    
                        player2turn = False
                                    
                    if player3turn == "yes":
                                    
                        player3turn = True
                                    
                    elif player3turn == "no":
                                    
                        player3turn = False
                        
                    if player1.balance == 0 and player2.balance == 0 and player3.balance == 0:
                        print("It looks like everyone is out of money!")
                        game_on = False
                        playing = False
                                    
                    if player1turn == False and player2turn == False and player3turn == False:
                        print("It looks like everybody walked!")
                        game_on = False
                        playing = False
                                    
                    break
# Out:
# Welcome to BlackJack!
# Are you ready to play?Yes
# Great! Let's begin.
# Player 1, what is your name?Ryan
# And how much are you bringing to the table?Andrew
# Player 1, what is your name?Ryan
# And how much are you bringing to the table?5000
# Ryan has 5000 dollars.
# Player 2, what is your name?Andrew
# And how much are you bringing to the table?23
# Player 2, what is your name?Andrew
# And how much are you bringing to the table?4000
# Andrew has 4000 dollars.
